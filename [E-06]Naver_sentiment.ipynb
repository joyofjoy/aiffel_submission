# %% [markdown]
# # 1. 데이터 확인과 준비

# %%
import pandas as pd
import urllib.request
# %matplotlib inline
import matplotlib.pyplot as plt
import re
from konlpy.tag import Okt
from tensorflow import keras
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences
from collections import Counter
import os
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# 데이터 읽기
train_data = pd.read_table('~/aiffel/sentiment_classification/data/ratings_train.txt')
test_data = pd.read_table('~/aiffel/sentiment_classification/data/ratings_test.txt')

train_data.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %% [markdown]
# # 2. Dataloader 준비

# %% [markdown]
# - 데이터의 중복 제거
# - NaN 결측치 제거
# - 한국어 토크나이저로 토큰화
# - 불용어(Stopwords) 제거
# - 사전word_to_index 구성
# - 텍스트 스트링을 사전 인덱스 스트링으로 변환
# - X_train, y_train, X_test, y_test, word_to_index 리턴

# %%
from konlpy.tag import Mecab
tokenizer = Mecab()
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# load_data 함수
def load_data(train_data, test_data, num_words=10000):
    train_data.drop_duplicates(subset=['document'], inplace=True)
    train_data = train_data.dropna(how = 'any') 
    test_data.drop_duplicates(subset=['document'], inplace=True)
    test_data = test_data.dropna(how = 'any') 

    x_train = []
    for sentence in train_data['document']:
        temp_x = tokenizer.morphs(sentence) # 토큰화
        temp_x = [word for word in temp_x if word not in stopwords] # 불용어 제거
        x_train.append(temp_x)

    x_test = []
    for sentence in test_data['document']:
        temp_x = tokenizer.morphs(sentence) # 토큰화
        temp_x = [word for word in temp_x if word not in stopwords] # 불용어 제거
        x_test.append(temp_x)

    words = np.concatenate(x_train).tolist()
    counter = Counter(words)
    counter = counter.most_common(10000-4)
    vocab = ['<PAD>', '<BOS>', '<UNK>', '<UNUSED>'] + [key for key, _ in counter]
    word_to_index = {word:index for index, word in enumerate(vocab)}

    def wordlist_to_indexlist(wordlist):
        return [word_to_index[word] if word in word_to_index else word_to_index['<UNK>'] for word in wordlist]

    x_train = list(map(wordlist_to_indexlist, x_train))
    x_test = list(map(wordlist_to_indexlist, x_test))

    return x_train, np.array(list(train_data['label'])), x_test, np.array(list(test_data['label'])), word_to_index

x_train, y_train, x_test, y_test, word_to_index = load_data(train_data, test_data)

# %%
index_to_word = {index:word for word, index in word_to_index.items()}

# 문장 1개를 활용할 딕셔너리와 함께 주면, 단어 인덱스 리스트 벡터로 변환해 주는 함수
# 단, 모든 문장은 <BOS>로 시작
def get_encoded_sentence(sentence, word_to_index):
    return [word_to_index['<BOS>']]+[word_to_index[word] if word in word_to_index else word_to_index['<UNK>'] for word in sentence.split()]

# 여러 개의 문장 리스트를 한꺼번에 단어 인덱스 리스트 벡터로 encode해 주는 함수 
def get_encoded_sentences(sentences, word_to_index):
    return [get_encoded_sentence(sentence, word_to_index) for sentence in sentences]

# 숫자 벡터로 encode된 문장을 원래대로 decode하는 함수
def get_decoded_sentence(encoded_sentence, index_to_word):
    return ' '.join(index_to_word[index] if index in index_to_word else '<UNK>' for index in encoded_sentence[1:])  #[1:]를 통해 <BOS>를 제외

# 여러개의 숫자 벡터로 encode된 문장을 한꺼번에 원래대로 decode하는 함수
def get_decoded_sentences(encoded_sentences, index_to_word):
    return [get_decoded_sentence(encoded_sentence, index_to_word) for encoded_sentence in encoded_sentences]

print("훈련 샘플 개수: {}, 테스트 개수: {}".format(len(x_train), len(x_test)))

# decoding
print(get_decoded_sentence(x_train[0], index_to_word))
print('라벨: ', y_train[0])  # 1번째 리뷰데이터의 라벨
# Out:
# 훈련 샘플 개수: 146182, 테스트 개수: 49157
# 더 빙 . . 진짜 짜증 나 네요 목소리
# 라벨:  0

# %% [markdown]
# # 3. 모델 구성을 위한 데이터 분석 및 가공

# %% [markdown]
# - 데이터셋 내 문장 길이 분포
# - 적절한 최대 문장 길이 지정
# - keras.preprocessing.sequence.pad_sequences 을 활용한 패딩 추가

# %%
# 텍스트데이터 문장길이의 리스트를 생성한 후
total_data_text = list(x_train) + list(x_test)

# 문장길이의 평균값, 최대값, 표준편차를 계산
num_tokens = [len(tokens) for tokens in total_data_text]
num_tokens = np.array(num_tokens)

print('문장길이 평균 : ', np.mean(num_tokens))
print('문장길이 최대 : ', np.max(num_tokens))
print('문장길이 표준편차 : ', np.std(num_tokens))
plt.clf()

plt.hist([len(s) for s in total_data_text], bins=100)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

# 예를들어, 최대 길이를 (평균 + 2*표준편차)로 가정
max_tokens = np.mean(num_tokens) + 3 * np.std(num_tokens)
maxlen = int(max_tokens)
print('pad_sequences maxlen : ', maxlen)
print('전체 문장의 {}%가 maxlen 설정값 이내에 포함됩니다. '.format(np.sum(num_tokens < max_tokens) / len(num_tokens)))

# padding
x_train = keras.preprocessing.sequence.pad_sequences(x_train,
                                                        value=word_to_index["<PAD>"],
                                                        padding='pre', # 혹은 'pre'
                                                        maxlen=maxlen)

x_test = keras.preprocessing.sequence.pad_sequences(x_test,
                                                       value=word_to_index["<PAD>"],
                                                       padding='pre', # 혹은 'pre'
                                                       maxlen=maxlen)

print(x_train.shape)
# Out:
# 문장길이 평균 :  15.96940191154864
# 문장길이 최대 :  116
# 문장길이 표준편차 :  12.843571191092
# pad_sequences maxlen :  54
# 전체 문장의 0.9720946661956905%가 maxlen 설정값 이내에 포함됩니다.
# (146182, 54)

# %% [markdown]
# # 4. 모델 구성 및 validation set 구성 + 학습 및 시각화

# %% [markdown]
# LSTM, 1D CNN, 1 layer MaxPooling -  3가지 방법으로 각각 학습시켜 보기.

# %% [markdown]
# ## (1) LSTM으로 해 보기

# %%
vocab_size = 10000    # 어휘 사전의 크기입니다(10,000개의 단어)
word_vector_dim = 16  # 워드 벡터의 차원수 (변경가능한 하이퍼파라미터)

# 모델 설계
model = keras.Sequential()
model.add(keras.layers.Embedding(vocab_size, word_vector_dim, input_shape=(None,)))
model.add(keras.layers.LSTM(128))
model.add(keras.layers.Dense(8, activation='relu'))
model.add(keras.layers.Dense(1, activation='sigmoid'))

model.summary()

# validation set 10000건 분리
x_val = x_train[:10000]   
y_val = y_train[:10000]

# validation set을 제외한 나머지 15000건
partial_x_train = x_train[10000:]  
partial_y_train = y_train[10000:]

print(partial_x_train.shape)
print(partial_y_train.shape)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

epochs=20

history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=epochs,
                    batch_size=512,
                    validation_data=(x_val, y_val),
                    verbose=1)

# Early-stopping 적용

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# 모델 평가
results = model.evaluate(x_test,  y_test, verbose=2)

print(results)

# 모델의 fitting 과정 중의 정보들이 history 변수에 저장
history_dict = history.history
print(history_dict.keys()) # epoch에 따른 그래프를 그려볼 수 있는 항목들

# Epoch별 Loss와 Accuracy 시각화

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()
plt.show()


# 테스트셋으로 평가

results = model.evaluate(x_test,  y_test, verbose=2)
print('Test 결과:',results)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_4 (Embedding)      (None, None, 16)          160000
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 128)               74240
# _________________________________________________________________
# dense_8 (Dense)              (None, 8)                 1032
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 235,281
# Trainable params: 235,281
# Non-trainable params: 0
# _________________________________________________________________
# (136182, 54)
# (136182,)
# Epoch 1/20
# 266/266 [==============================] - 4s 12ms/step - loss: 0.4603 - accuracy: 0.7796 - val_loss: 0.3691 - val_accuracy: 0.8367
# Epoch 2/20
# 266/266 [==============================] - 3s 10ms/step - loss: 0.3348 - accuracy: 0.8577 - val_loss: 0.3397 - val_accuracy: 0.8513
# Epoch 3/20
# 266/266 [==============================] - 3s 11ms/step - loss: 0.3162 - accuracy: 0.8677 - val_loss: 0.3400 - val_accuracy: 0.8541
# Epoch 4/20
# 266/266 [==============================] - 3s 10ms/step - loss: 0.3054 - accuracy: 0.8733 - val_loss: 0.3352 - val_accuracy: 0.8542
# Epoch 5/20
# 266/266 [==============================] - 3s 10ms/step - loss: 0.2910 - accuracy: 0.8797 - val_loss: 0.3382 - val_accuracy: 0.8549
# Epoch 6/20
# 266/266 [==============================] - 3s 10ms/step - loss: 0.2740 - accuracy: 0.8862 - val_loss: 0.3312 - val_accuracy: 0.8573
# Epoch 7/20
# 266/266 [==============================] - 3s 11ms/step - loss: 0.2564 - accuracy: 0.8944 - val_loss: 0.3404 - val_accuracy: 0.8574
# Epoch 8/20
# 266/266 [==============================] - 3s 11ms/step - loss: 0.2417 - accuracy: 0.9017 - val_loss: 0.3373 - val_accuracy: 0.8582
# Epoch 9/20
# 266/266 [==============================] - 3s 11ms/step - loss: 0.2274 - accuracy: 0.9076 - val_loss: 0.3429 - val_accuracy: 0.8567
# Epoch 10/20
# 266/266 [==============================] - 3s 11ms/step - loss: 0.2149 - accuracy: 0.9142 - val_loss: 0.3604 - val_accuracy: 0.8577
# Epoch 11/20
# 266/266 [==============================] - 3s 11ms/step - loss: 0.2021 - accuracy: 0.9205 - val_loss: 0.3676 - val_accuracy: 0.8533
# Epoch 12/20
# 266/266 [==============================] - 3s 11ms/step - loss: 0.1899 - accuracy: 0.9257 - val_loss: 0.3944 - val_accuracy: 0.8541
# Epoch 13/20
# 266/266 [==============================] - 3s 11ms/step - loss: 0.1774 - accuracy: 0.9313 - val_loss: 0.4068 - val_accuracy: 0.8498
# Epoch 14/20
# 266/266 [==============================] - 3s 11ms/step - loss: 0.1658 - accuracy: 0.9361 - val_loss: 0.4362 - val_accuracy: 0.8511
# Epoch 15/20
# 266/266 [==============================] - 3s 11ms/step - loss: 0.1572 - accuracy: 0.9394 - val_loss: 0.4520 - val_accuracy: 0.8463
# Epoch 16/20
# 266/266 [==============================] - 3s 11ms/step - loss: 0.1483 - accuracy: 0.9426 - val_loss: 0.5040 - val_accuracy: 0.8457
# Epoch 17/20
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1399 - accuracy: 0.9455 - val_loss: 0.5217 - val_accuracy: 0.8455
# Epoch 18/20
# 266/266 [==============================] - 3s 11ms/step - loss: 0.1314 - accuracy: 0.9488 - val_loss: 0.5678 - val_accuracy: 0.8420
# Epoch 19/20
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1233 - accuracy: 0.9519 - val_loss: 0.5995 - val_accuracy: 0.8454
# Epoch 20/20
# 266/266 [==============================] - 3s 10ms/step - loss: 0.1181 - accuracy: 0.9536 - val_loss: 0.6002 - val_accuracy: 0.8429
# 1537/1537 - 4s - loss: 0.5970 - accuracy: 0.8393
# [0.5969534516334534, 0.8392701148986816]
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 1537/1537 - 4s - loss: 0.5970 - accuracy: 0.8393
# Test 결과: [0.5969534516334534, 0.8392701148986816]

# %% [markdown]
# ## (2) 1D CNN으로 해보기

# %%
vocab_size = 10000    # 어휘 사전의 크기입니다(10,000개의 단어)
word_vector_dim = 16  # 워드 벡터의 차원수 (변경가능한 하이퍼파라미터)

# 모델 설계
model = tf.keras.Sequential()
model.add(tf.keras.layers.Embedding(vocab_size, word_vector_dim, input_shape=(None,)))
model.add(tf.keras.layers.Conv1D(16, 7, activation='relu'))
model.add(tf.keras.layers.MaxPooling1D(5))
model.add(tf.keras.layers.Conv1D(16, 7, activation='relu'))
model.add(tf.keras.layers.GlobalMaxPooling1D())
model.add(tf.keras.layers.Dense(8, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))  # 최종 출력은 긍정/부정을 나타내는 1dim 입니다.

model.summary()

# validation set 10000건 분리
x_val = x_train[:10000]   
y_val = y_train[:10000]

# validation set을 제외한 나머지 15000건
partial_x_train = x_train[10000:]  
partial_y_train = y_train[10000:]

print(partial_x_train.shape)
print(partial_y_train.shape)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

epochs=20

history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=epochs,
                    batch_size=512,
                    validation_data=(x_val, y_val),
                    verbose=1)

# 모델 평가
results = model.evaluate(x_test,  y_test, verbose=2)

print(results)

# 모델의 fitting 과정 중의 정보들이 history 변수에 저장
history_dict = history.history
print(history_dict.keys()) # epoch에 따른 그래프를 그려볼 수 있는 항목들

# Epoch별 Loss와 Accuracy 시각화

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()
plt.show()

# 테스트셋으로 평가

results = model.evaluate(x_test,  y_test, verbose=2)
print('Test 결과:',results)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 16)          160000
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 16)          1808
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, None, 16)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 16)          1808
# _________________________________________________________________
# global_max_pooling1d (Global (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 163,761
# Trainable params: 163,761
# Non-trainable params: 0
# _________________________________________________________________
# (136182, 54)
# (136182,)
# Epoch 1/20
# 266/266 [==============================] - 3s 6ms/step - loss: 0.5395 - accuracy: 0.7129 - val_loss: 0.4309 - val_accuracy: 0.7859
# Epoch 2/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.4031 - accuracy: 0.8094 - val_loss: 0.4204 - val_accuracy: 0.7957
# Epoch 3/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.3721 - accuracy: 0.8263 - val_loss: 0.4190 - val_accuracy: 0.7917
# Epoch 4/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.3454 - accuracy: 0.8412 - val_loss: 0.4231 - val_accuracy: 0.7944
# Epoch 5/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.3176 - accuracy: 0.8565 - val_loss: 0.4389 - val_accuracy: 0.7904
# Epoch 6/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.2887 - accuracy: 0.8710 - val_loss: 0.4562 - val_accuracy: 0.7919
# Epoch 7/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.2585 - accuracy: 0.8867 - val_loss: 0.4911 - val_accuracy: 0.7860
# Epoch 8/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.2314 - accuracy: 0.8999 - val_loss: 0.5336 - val_accuracy: 0.7845
# Epoch 9/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.2076 - accuracy: 0.9097 - val_loss: 0.5683 - val_accuracy: 0.7815
# Epoch 10/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.1890 - accuracy: 0.9174 - val_loss: 0.6123 - val_accuracy: 0.7770
# Epoch 11/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.1726 - accuracy: 0.9240 - val_loss: 0.6647 - val_accuracy: 0.7785
# Epoch 12/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.1602 - accuracy: 0.9289 - val_loss: 0.7038 - val_accuracy: 0.7716
# Epoch 13/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.1495 - accuracy: 0.9331 - val_loss: 0.7521 - val_accuracy: 0.7708
# Epoch 14/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.1407 - accuracy: 0.9365 - val_loss: 0.8245 - val_accuracy: 0.7659
# Epoch 15/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.1335 - accuracy: 0.9398 - val_loss: 0.8551 - val_accuracy: 0.7638
# Epoch 16/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.1275 - accuracy: 0.9414 - val_loss: 0.9150 - val_accuracy: 0.7635
# Epoch 17/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.1233 - accuracy: 0.9426 - val_loss: 0.9550 - val_accuracy: 0.7659
# Epoch 18/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.1194 - accuracy: 0.9441 - val_loss: 0.9931 - val_accuracy: 0.7625
# Epoch 19/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.1147 - accuracy: 0.9458 - val_loss: 1.0864 - val_accuracy: 0.7578
# Epoch 20/20
# 266/266 [==============================] - 1s 5ms/step - loss: 0.1115 - accuracy: 0.9472 - val_loss: 1.1006 - val_accuracy: 0.7543
# 1537/1537 - 3s - loss: 1.0776 - accuracy: 0.7576
# [1.077593207359314, 0.7575726509094238]
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 1537/1537 - 3s - loss: 1.0776 - accuracy: 0.7576
# Test 결과: [1.077593207359314, 0.7575726509094238]

# %% [markdown]
# ## (3) Maxpooling layer 하나로만 학습해 보기

# %%
vocab_size = 10000    # 어휘 사전의 크기입니다(10,000개의 단어)
word_vector_dim = 16  # 워드 벡터의 차원수 (변경가능한 하이퍼파라미터)

# 모델 설계
model = tf.keras.Sequential()
model.add(tf.keras.layers.Embedding(vocab_size, word_vector_dim, input_shape=(None,)))
model.add(tf.keras.layers.GlobalMaxPooling1D())
model.add(tf.keras.layers.Dense(8, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))  # 최종 출력은 긍정/부정을 나타내는 1dim 입니다.

model.summary()

# validation set 10000건 분리
x_val = x_train[:10000]   
y_val = y_train[:10000]

# validation set을 제외한 나머지 15000건
partial_x_train = x_train[10000:]  
partial_y_train = y_train[10000:]

print(partial_x_train.shape)
print(partial_y_train.shape)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

epochs=20

history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=epochs,
                    batch_size=512,
                    validation_data=(x_val, y_val),
                    verbose=1)

# 모델 평가
results = model.evaluate(x_test,  y_test, verbose=2)

print(results)

# 모델의 fitting 과정 중의 정보들이 history 변수에 저장
history_dict = history.history
print(history_dict.keys()) # epoch에 따른 그래프를 그려볼 수 있는 항목들

# Epoch별 Loss와 Accuracy 시각화

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()
plt.show()

# 테스트셋으로 평가

results = model.evaluate(x_test,  y_test, verbose=2)
print('Test 결과:',results)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_2 (Embedding)      (None, None, 16)          160000
# _________________________________________________________________
# global_max_pooling1d_1 (Glob (None, 16)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 160,145
# Trainable params: 160,145
# Non-trainable params: 0
# _________________________________________________________________
# (136182, 54)
# (136182,)
# Epoch 1/20
# 266/266 [==============================] - 1s 4ms/step - loss: 0.5585 - accuracy: 0.7655 - val_loss: 0.4044 - val_accuracy: 0.8260
# Epoch 2/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.3647 - accuracy: 0.8424 - val_loss: 0.3538 - val_accuracy: 0.8440
# Epoch 3/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.3212 - accuracy: 0.8641 - val_loss: 0.3450 - val_accuracy: 0.8459
# Epoch 4/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.2959 - accuracy: 0.8768 - val_loss: 0.3454 - val_accuracy: 0.8493
# Epoch 5/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.2767 - accuracy: 0.8862 - val_loss: 0.3489 - val_accuracy: 0.8486
# Epoch 6/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.2608 - accuracy: 0.8936 - val_loss: 0.3549 - val_accuracy: 0.8468
# Epoch 7/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.2479 - accuracy: 0.8995 - val_loss: 0.3624 - val_accuracy: 0.8470
# Epoch 8/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.2363 - accuracy: 0.9054 - val_loss: 0.3712 - val_accuracy: 0.8452
# Epoch 9/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.2260 - accuracy: 0.9099 - val_loss: 0.3803 - val_accuracy: 0.8446
# Epoch 10/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.2167 - accuracy: 0.9149 - val_loss: 0.3902 - val_accuracy: 0.8453
# Epoch 11/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.2086 - accuracy: 0.9186 - val_loss: 0.4007 - val_accuracy: 0.8420
# Epoch 12/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.2011 - accuracy: 0.9224 - val_loss: 0.4092 - val_accuracy: 0.8412
# Epoch 13/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.1942 - accuracy: 0.9259 - val_loss: 0.4207 - val_accuracy: 0.8375
# Epoch 14/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.1878 - accuracy: 0.9284 - val_loss: 0.4313 - val_accuracy: 0.8374
# Epoch 15/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.1818 - accuracy: 0.9313 - val_loss: 0.4397 - val_accuracy: 0.8381
# Epoch 16/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.1761 - accuracy: 0.9339 - val_loss: 0.4491 - val_accuracy: 0.8368
# Epoch 17/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.1712 - accuracy: 0.9364 - val_loss: 0.4618 - val_accuracy: 0.8348
# Epoch 18/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.1665 - accuracy: 0.9386 - val_loss: 0.4691 - val_accuracy: 0.8343
# Epoch 19/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.1621 - accuracy: 0.9405 - val_loss: 0.4812 - val_accuracy: 0.8343
# Epoch 20/20
# 266/266 [==============================] - 1s 3ms/step - loss: 0.1579 - accuracy: 0.9427 - val_loss: 0.4870 - val_accuracy: 0.8320
# 1537/1537 - 2s - loss: 0.5008 - accuracy: 0.8284
# [0.5008442401885986, 0.8284476399421692]
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# 1537/1537 - 2s - loss: 0.5008 - accuracy: 0.8284
# Test 결과: [0.5008442401885986, 0.8284476399421692]

# %% [markdown]
# # 5. 한국어 Word2Vec 임베딩 활용하여 성능 개선하기

# %% [markdown]
# 한국어 Word2Vec은 다음 경로에서 구할 수 있습니다.
#
# https://github.com/Kyubyong/wordvectors
# 위 링크에서 적절한 ko.bin을 찾아 이용하세요. 그리고 gensim 버전을 3.x.x로 낮춰야 오류가 나지 않습니다.

# %%
import gensim

word2vec_path = os.getenv('HOME')+'/aiffel/sentiment_classification/ko.bin'
pre_word2vec = gensim.models.Word2Vec.load(word2vec_path)


vocab_size = 10000    # 어휘 사전의 크기입니다(10,000개의 단어)
word_vector_dim = 200  # 워드 벡터의 차원수 (변경가능한 하이퍼파라미터)

embedding_matrix = np.random.rand(vocab_size, word_vector_dim)

# embedding_matrix에 Word2Vec 워드벡터를 단어 하나씩마다 차례차례 카피
for i in range(4,vocab_size):
    if index_to_word[i] in pre_word2vec:
        embedding_matrix[i] = pre_word2vec[index_to_word[i]]

# 모델 설계
from tensorflow.keras.initializers import Constant

vocab_size = 10000    # 어휘 사전의 크기입니다(10,000개의 단어)
word_vector_dim = 200  # 워드 벡터의 차원수 (변경가능한 하이퍼파라미터)

# 모델 구성
model = keras.Sequential()
model.add(keras.layers.Embedding(vocab_size, 
                                 word_vector_dim, 
                                 embeddings_initializer=Constant(embedding_matrix),  # 카피한 임베딩을 여기서 활용
                                 input_length=maxlen, 
                                 trainable=True))   # trainable을 True로 주면 Fine-tuning
model.add(keras.layers.LSTM(128))
model.add(keras.layers.Dense(8, activation='relu'))
model.add(keras.layers.Dense(1, activation='sigmoid'))

model.summary()

# 모델 학습
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

epochs=20

history = model.fit(partial_x_train,
                    partial_y_train,
                    epochs=epochs,
                    batch_size=100,
                    validation_data=(x_val, y_val),
                    verbose=1)

# 모델 평가
results = model.evaluate(x_test,  y_test, verbose=2)
print(results)

history_dict = history.history
print(history_dict.keys()) # epoch에 따른 그래프를 그려볼 수 있는 항목들

# 도식화 Training and Validation loss
import matplotlib.pyplot as plt

# Epoch별 Loss와 Accuracy 시각화

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.plot(history.history['val_loss'], 'r--', label='val_loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'g-', label='accuracy')
plt.plot(history.history['val_accuracy'], 'k--', label='val_accuracy')
plt.xlabel('Epoch')
plt.ylim(0.7, 1)
plt.legend()
plt.show()


es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
# Out:
# /tmp/ipykernel_6401/1521971136.py:14: DeprecationWarning: Call to deprecated `__contains__` (Method will be removed in 4.0.0, use self.wv.__contains__() instead).
#   if index_to_word[i] in pre_word2vec:
# /tmp/ipykernel_6401/1521971136.py:15: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   embedding_matrix[i] = pre_word2vec[index_to_word[i]]
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 54, 200)           2000000
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               168448
# _________________________________________________________________
# dense_6 (Dense)              (None, 8)                 1032
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 2,169,489
# Trainable params: 2,169,489
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1362/1362 [==============================] - 11s 7ms/step - loss: 0.3887 - accuracy: 0.8225 - val_loss: 0.3275 - val_accuracy: 0.8557
# Epoch 2/20
# 1362/1362 [==============================] - 10s 7ms/step - loss: 0.2906 - accuracy: 0.8772 - val_loss: 0.3132 - val_accuracy: 0.8658
# Epoch 3/20
# 1362/1362 [==============================] - 10s 7ms/step - loss: 0.2496 - accuracy: 0.8962 - val_loss: 0.3099 - val_accuracy: 0.8694
# Epoch 4/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.2129 - accuracy: 0.9132 - val_loss: 0.3275 - val_accuracy: 0.8691
# Epoch 5/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.1754 - accuracy: 0.9305 - val_loss: 0.3665 - val_accuracy: 0.8626
# Epoch 6/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.1395 - accuracy: 0.9457 - val_loss: 0.4080 - val_accuracy: 0.8581
# Epoch 7/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.1110 - accuracy: 0.9578 - val_loss: 0.4667 - val_accuracy: 0.8626
# Epoch 8/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.0845 - accuracy: 0.9682 - val_loss: 0.5534 - val_accuracy: 0.8546
# Epoch 9/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.0689 - accuracy: 0.9743 - val_loss: 0.6004 - val_accuracy: 0.8537
# Epoch 10/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.0569 - accuracy: 0.9781 - val_loss: 0.6256 - val_accuracy: 0.8547
# Epoch 11/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.0480 - accuracy: 0.9817 - val_loss: 0.7043 - val_accuracy: 0.8541
# Epoch 12/20
# 1362/1362 [==============================] - 10s 7ms/step - loss: 0.0403 - accuracy: 0.9847 - val_loss: 0.7895 - val_accuracy: 0.8478
# Epoch 13/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.0352 - accuracy: 0.9865 - val_loss: 0.8225 - val_accuracy: 0.8490
# Epoch 14/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.0326 - accuracy: 0.9875 - val_loss: 0.8466 - val_accuracy: 0.8503
# Epoch 15/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.0320 - accuracy: 0.9880 - val_loss: 0.8849 - val_accuracy: 0.8518
# Epoch 16/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.0263 - accuracy: 0.9898 - val_loss: 0.8897 - val_accuracy: 0.8502
# Epoch 17/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.0259 - accuracy: 0.9904 - val_loss: 0.9612 - val_accuracy: 0.8515
# Epoch 18/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.0231 - accuracy: 0.9909 - val_loss: 0.9890 - val_accuracy: 0.8522
# Epoch 19/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.0220 - accuracy: 0.9915 - val_loss: 0.9821 - val_accuracy: 0.8524
# Epoch 20/20
# 1362/1362 [==============================] - 9s 7ms/step - loss: 0.0210 - accuracy: 0.9921 - val_loss: 1.0061 - val_accuracy: 0.8521
# 1537/1537 - 4s - loss: 0.9913 - accuracy: 0.8496
# [0.9913028478622437, 0.8495839834213257]
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # 회고
#
# 1. 다양한 방법을 써 봤는데 모두 초기부터 overfitting이 시작되었다.개선하고 싶은데 잘 안된다.
# 2. 한국어 NLP는 쉽지 않다. 뭔가 고정된 프로세스를 정리하고 한국어 임베딩은 특히 공부가 필요하다.
# 3. NLP에서 1D CNN으로도 가능하다는 것을 알게 되었다.
